# %%
df.plot(kind='box', figsize=(10,5))
plt.show()

# %% [markdown]
# Insights
# The dataset was successfully loaded and explored using Python and Pandas.
# Data cleaning was performed by checking for missing values and understanding the structure of the dataset.
# Statistical summaries were generated to understand the distribution and characteristics of the data.
# Visualizations such as histograms, box plots, and a correlation matrix were used to identify patterns, trends, and relationships between variables.
# The correlation analysis highlighted the strength of relationships among the numerical features, helping to identify important influencing factors.
# Outliers and data distribution were examined to better understand the quality of the dataset.
# Overall, the Exploratory Data Analysis (EDA) provided valuable insights into the dataset and established a strong foundation for future data analysis and machine learning tasks.
# Conclusion
#
# The Exploratory Data Analysis project helped in understanding the dataset through statistical analysis and data visualization. It revealed important patterns, relationships, and trends while identifying any potential data quality issues. This analysis improves decision-making and prepares the dataset for further predictive modeling and machine learning applications.

# %%
import matplotlib.pyplot as plt

corr = df.corr(numeric_only=True)

plt.figure(figsize=(8,6))
plt.imshow(corr, cmap='coolwarm')
plt.colorbar()
plt.xticks(range(len(corr.columns)), corr.columns, rotation=90)
plt.yticks(range(len(corr.columns)), corr.columns)
plt.show()

# %%
df.hist(figsize=(10,8))
plt.show()

# %%
df.info()
df.shape
df.describe()
df.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 251 entries, 0 to 250
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Item Code      251 non-null    int64
#  1   Item Name      251 non-null    object
#  2   Loss Rate (%)  251 non-null    float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 6.0+ KB
# Item Code        0
# Item Name        0
# Loss Rate (%)    0
# dtype: int64

# %%
df = pd.read_csv("annex4.csv")
df.head()
# Out:
#          Item Code                 Item Name  Loss Rate (%)
# 0  102900005115168          Niushou Shengcai           4.39
# 1  102900005115199         Sichuan Red Cedar          10.46
# 2  102900005115250  Xixia Black Mushroom (1)          10.80
# 3  102900005115625     Local Xiaomao Cabbage           0.18
# 4  102900005115748              White Caitai           8.78

# %%
import pandas as pd
import matplotlib.pyplot as plt
